# %% [markdown]
# # Extracting a pokemons learn set
#
# This Jupyter notebook is for scaping data from Serebii.net. Specificly a pokemons pokemon yellow learn set

# %%
# Import libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # Important Note
#
# Each pokemons page has a unique format, so you'll need to change the value inside of dfs in order to extract the correct data

# %%
# Create an URL object
url = 'https://www.serebii.net/pokedex/141.shtml' # The pokemons page
# Create object page
page = requests.get(url)

# %%
# reading all the tables as DF
dfs = pd.read_html(url)

# %%
# Defining data set
lvl_up_set = dfs[12] # Change the value here if you're not getting the correct data, just jump around 
                     # till you find the correct table
lvl_up_set
# Out:
#                         0                      1  \
# 0   Generation I Level Up  Generation I Level Up
# 1                   Level            Attack Name
# 2                       —                Scratch
# 3                       —                Scratch
# 4                       —                 Harden
# 5                       —                 Harden
# 6                       —                 Absorb
# 7                       —                 Absorb
# 8                      34                 Absorb
# 9                      34                 Absorb
# 10                     39                  Slash
# 11                     39                  Slash
# 12                     46                   Leer
# 13                     46                   Leer
# 14                     53             Hydro Pump
# 15                     53             Hydro Pump
#
#                                                     2  \
# 0                               Generation I Level Up
# 1                                                Type
# 2                                                 NaN
# 3   A NORMAL-type attack. Sharp claws are used to ...
# 4                                                 NaN
# 5   Raises the user's DEFENSE. Useful when battlin...
# 6                                                 NaN
# 7   A GRASS-type attack. It adds half the HP it dr...
# 8                                                 NaN
# 9   A GRASS-type attack. It adds half the HP it dr...
# 10                                                NaN
# 11  A NORMAL-type attack. It has a high probabilit...
# 12                                                NaN
# 13  A technique that lowers the target's DEFENSE. ...
# 14                                                NaN
# 15  The strongest WATER-type attack. However, whil...
#
#                                                     3  \
# 0                               Generation I Level Up
# 1                                                Att.
# 2                                                  40
# 3   A NORMAL-type attack. Sharp claws are used to ...
# 4                                                  --
# 5   Raises the user's DEFENSE. Useful when battlin...
# 6                                                  20
# 7   A GRASS-type attack. It adds half the HP it dr...
# 8                                                  20
# 9   A GRASS-type attack. It adds half the HP it dr...
# 10                                                 70
# 11  A NORMAL-type attack. It has a high probabilit...
# 12                                                 --
# 13  A technique that lowers the target's DEFENSE. ...
# 14                                                120
# 15  The strongest WATER-type attack. However, whil...
#
#                                                     4  \
# 0                               Generation I Level Up
# 1                                                Acc.
# 2                                                 100
# 3   A NORMAL-type attack. Sharp claws are used to ...
# 4                                                 100
# 5   Raises the user's DEFENSE. Useful when battlin...
# 6                                                 100
# 7   A GRASS-type attack. It adds half the HP it dr...
# 8                                                 100
# 9   A GRASS-type attack. It adds half the HP it dr...
# 10                                                100
# 11  A NORMAL-type attack. It has a high probabilit...
# 12                                                100
# 13  A technique that lowers the target's DEFENSE. ...
# 14                                                 80
# 15  The strongest WATER-type attack. However, whil...
#
#                                                     5  \
# 0                               Generation I Level Up
# 1                                                  PP
# 2                                                  35
# 3   A NORMAL-type attack. Sharp claws are used to ...
# 4                                                  30
# 5   Raises the user's DEFENSE. Useful when battlin...
# 6                                                  20
# 7   A GRASS-type attack. It adds half the HP it dr...
# 8                                                  20
# 9   A GRASS-type attack. It adds half the HP it dr...
# 10                                                 20
# 11  A NORMAL-type attack. It has a high probabilit...
# 12                                                 30
# 13  A technique that lowers the target's DEFENSE. ...
# 14                                                  5
# 15  The strongest WATER-type attack. However, whil...
#
#                                                     6  \
# 0                               Generation I Level Up
# 1                                            Effect %
# 2                                                  --
# 3   A NORMAL-type attack. Sharp claws are used to ...
# 4                                                  --
# 5   Raises the user's DEFENSE. Useful when battlin...
# 6                                                  --
# 7   A GRASS-type attack. It adds half the HP it dr...
# 8                                                  --
# 9   A GRASS-type attack. It adds half the HP it dr...
# 10                                                 --
# 11  A NORMAL-type attack. It has a high probabilit...
# 12                                                 --
# 13  A technique that lowers the target's DEFENSE. ...
# 14                                                 --
# 15  The strongest WATER-type attack. However, whil...
#
#                                                     7  \
# 0                               Generation I Level Up
# 1                                                 NaN
# 2                                                 NaN
# 3   A NORMAL-type attack. Sharp claws are used to ...
# 4                                                 NaN
# 5   Raises the user's DEFENSE. Useful when battlin...
# 6                                                 NaN
# 7   A GRASS-type attack. It adds half the HP it dr...
# 8                                                 NaN
# 9   A GRASS-type attack. It adds half the HP it dr...
# 10                                                NaN
# 11  A NORMAL-type attack. It has a high probabilit...
# 12                                                NaN
# 13  A technique that lowers the target's DEFENSE. ...
# 14                                                NaN
# 15  The strongest WATER-type attack. However, whil...
#
#                                                     8  \
# 0                               Generation I Level Up
# 1                                                 NaN
# 2                                                 NaN
# 3   A NORMAL-type attack. Sharp claws are used to ...
# 4                                                 NaN
# 5   Raises the user's DEFENSE. Useful when battlin...
# 6                                                 NaN
# 7   A GRASS-type attack. It adds half the HP it dr...
# 8                                                 NaN
# 9   A GRASS-type attack. It adds half the HP it dr...
# 10                                                NaN
# 11  A NORMAL-type attack. It has a high probabilit...
# 12                                                NaN
# 13  A technique that lowers the target's DEFENSE. ...
# 14                                                NaN
# 15  The strongest WATER-type attack. However, whil...
#
#                                                     9
# 0                               Generation I Level Up
# 1                                                 NaN
# 2                                                 NaN
# 3   A NORMAL-type attack. Sharp claws are used to ...
# 4                                                 NaN
# 5   Raises the user's DEFENSE. Useful when battlin...
# 6                                                 NaN
# 7   A GRASS-type attack. It adds half the HP it dr...
# 8                                                 NaN
# 9   A GRASS-type attack. It adds half the HP it dr...
# 10                                                NaN
# 11  A NORMAL-type attack. It has a high probabilit...
# 12                                                NaN
# 13  A technique that lowers the target's DEFENSE. ...
# 14                                                NaN
# 15  The strongest WATER-type attack. However, whil...

# %%
# Defining data set
tm_set = dfs[13]
tm_set
# Out:
#                   0                1  \
# 0   TM & HM Attacks  TM & HM Attacks
# 1           TM/HM #      Attack Name
# 2              TM02       Razor Wind
# 3              TM02       Razor Wind
# 4              TM03     Swords Dance
# 5              TM03     Swords Dance
# 6              TM05        Mega Kick
# 7              TM05        Mega Kick
# 8              TM06            Toxic
# 9              TM06            Toxic
# 10             TM08        Body Slam
# 11             TM08        Body Slam
# 12             TM09        Take Down
# 13             TM09        Take Down
# 14             TM10      Double-Edge
# 15             TM10      Double-Edge
# 16             TM11      Bubble Beam
# 17             TM11      Bubble Beam
# 18             TM12        Water Gun
# 19             TM12        Water Gun
# 20             TM13         Ice Beam
# 21             TM13         Ice Beam
# 22             TM14         Blizzard
# 23             TM14         Blizzard
# 24             TM15       Hyper Beam
# 25             TM15       Hyper Beam
# 26             TM17       Submission
# 27             TM17       Submission
# 28             TM19     Seismic Toss
# 29             TM19     Seismic Toss
# 30             TM20             Rage
# 31             TM20             Rage
# 32             TM31            Mimic
# 33             TM31            Mimic
# 34             TM32      Double Team
# 35             TM32      Double Team
# 36             TM33          Reflect
# 37             TM33          Reflect
# 38             TM34             Bide
# 39             TM34             Bide
# 40             TM40       Skull Bash
# 41             TM40       Skull Bash
# 42             TM44             Rest
# 43             TM44             Rest
# 44             TM50       Substitute
# 45             TM50       Substitute
# 46             HM01              Cut
# 47             HM01              Cut
# 48             HM03             Surf
# 49             HM03             Surf
#
#                                                     2  \
# 0                                     TM & HM Attacks
# 1                                                Type
# 2                                                 NaN
# 3   A two-turn attack with the wind attack in the ...
# 4                                                 NaN
# 5   A special move that greatly boosts the user's ...
# 6                                                 NaN
# 7   A NORMAL-type attack. Out of all the Pokémon k...
# 8                                                 NaN
# 9   A technique that badly poisons the target. The...
# 10                                                NaN
# 11  A NORMAL-type attack. Has a one-in-three chanc...
# 12                                                NaN
# 13  A charging attack. One quarter of the damage i...
# 14                                                NaN
# 15  A charging tackle attack. One quarter of the d...
# 16                                                NaN
# 17  A WATER-type attack. Has a one-in-three chance...
# 18                                                NaN
# 19  A WATER-type attack. Stronger than BUBBLE. Man...
# 20                                                NaN
# 21  An ICE-type attack. Has a one-in-ten chance of...
# 22                                                NaN
# 23  The strongest ICE-type attack. Has a one-in-te...
# 24                                                NaN
# 25  An extremely powerful attack. The attacker bec...
# 26                                                NaN
# 27  The strongest FIGHTING attack. One quarter of ...
# 28                                                NaN
# 29  A FIGHTING-type attack. Throws the target with...
# 30                                                NaN
# 31  A non-stop attack move. The user's ATTACK powe...
# 32                                                NaN
# 33  A move for learning one of the opponent's move...
# 34                                                NaN
# 35  Creates illusionary copies of the user. The co...
# 36                                                NaN
# 37  Reduces damage from physical attacks by about ...
# 38                                                NaN
# 39  The user waits for several turns. At the end, ...
# 40                                                NaN
# 41  In the first turn, the attacker tucks in its h...
# 42                                                NaN
# 43  The user takes a nap to fully restore its HP a...
# 44                                                NaN
# 45  Uses 1/4 of the user's maximum HP to create a ...
# 46                                                NaN
# 47  A NORMAL-type attack. Also used for cutting sm...
# 48                                                NaN
# 49  A WATER-type attack. The power of this techniq...
#
#                                                     3  \
# 0                                     TM & HM Attacks
# 1                                                Att.
# 2                                                  80
# 3   A two-turn attack with the wind attack in the ...
# 4                                                  --
# 5   A special move that greatly boosts the user's ...
# 6                                                 120
# 7   A NORMAL-type attack. Out of all the Pokémon k...
# 8                                                  --
# 9   A technique that badly poisons the target. The...
# 10                                                 85
# 11  A NORMAL-type attack. Has a one-in-three chanc...
# 12                                                 90
# 13  A charging attack. One quarter of the damage i...
# 14                                                100
# 15  A charging tackle attack. One quarter of the d...
# 16                                                 65
# 17  A WATER-type attack. Has a one-in-three chance...
# 18                                                 40
# 19  A WATER-type attack. Stronger than BUBBLE. Man...
# 20                                                 95
# 21  An ICE-type attack. Has a one-in-ten chance of...
# 22                                                120
# 23  The strongest ICE-type attack. Has a one-in-te...
# 24                                                150
# 25  An extremely powerful attack. The attacker bec...
# 26                                                 80
# 27  The strongest FIGHTING attack. One quarter of ...
# 28                                                 ??
# 29  A FIGHTING-type attack. Throws the target with...
# 30                                                 20
# 31  A non-stop attack move. The user's ATTACK powe...
# 32                                                 --
# 33  A move for learning one of the opponent's move...
# 34                                                 --
# 35  Creates illusionary copies of the user. The co...
# 36                                                 --
# 37  Reduces damage from physical attacks by about ...
# 38                                                 --
# 39  The user waits for several turns. At the end, ...
# 40                                                100
# 41  In the first turn, the attacker tucks in its h...
# 42                                                 --
# 43  The user takes a nap to fully restore its HP a...
# 44                                                 --
# 45  Uses 1/4 of the user's maximum HP to create a ...
# 46                                                 50
# 47  A NORMAL-type attack. Also used for cutting sm...
# 48                                                 95
# 49  A WATER-type attack. The power of this techniq...
#
#                                                     4  \
# 0                                     TM & HM Attacks
# 1                                                Acc.
# 2                                                74.6
# 3   A two-turn attack with the wind attack in the ...
# 4                                                 100
# 5   A special move that greatly boosts the user's ...
# 6                                                74.6
# 7   A NORMAL-type attack. Out of all the Pokémon k...
# 8                                                  85
# 9   A technique that badly poisons the target. The...
# 10                                                100
# 11  A NORMAL-type attack. Has a one-in-three chanc...
# 12                                                 85
# 13  A charging attack. One quarter of the damage i...
# 14                                                100
# 15  A charging tackle attack. One quarter of the d...
# 16                                                100
# 17  A WATER-type attack. Has a one-in-three chance...
# 18                                                100
# 19  A WATER-type attack. Stronger than BUBBLE. Man...
# 20                                                100
# 21  An ICE-type attack. Has a one-in-ten chance of...
# 22                                                 90
# 23  The strongest ICE-type attack. Has a one-in-te...
# 24                                                 90
# 25  An extremely powerful attack. The attacker bec...
# 26                                                 80
# 27  The strongest FIGHTING attack. One quarter of ...
# 28                                                100
# 29  A FIGHTING-type attack. Throws the target with...
# 30                                                100
# 31  A non-stop attack move. The user's ATTACK powe...
# 32                                                100
# 33  A move for learning one of the opponent's move...
# 34                                                100
# 35  Creates illusionary copies of the user. The co...
# 36                                                100
# 37  Reduces damage from physical attacks by about ...
# 38                                                100
# 39  The user waits for several turns. At the end, ...
# 40                                                100
# 41  In the first turn, the attacker tucks in its h...
# 42                                                100
# 43  The user takes a nap to fully restore its HP a...
# 44                                                100
# 45  Uses 1/4 of the user's maximum HP to create a ...
# 46                                                 95
# 47  A NORMAL-type attack. Also used for cutting sm...
# 48                                                100
# 49  A WATER-type attack. The power of this techniq...
#
#                                                     5  \
# 0                                     TM & HM Attacks
# 1                                                  PP
# 2                                                  10
# 3   A two-turn attack with the wind attack in the ...
# 4                                                  30
# 5   A special move that greatly boosts the user's ...
# 6                                                   5
# 7   A NORMAL-type attack. Out of all the Pokémon k...
# 8                                                  10
# 9   A technique that badly poisons the target. The...
# 10                                                 15
# 11  A NORMAL-type attack. Has a one-in-three chanc...
# 12                                                 20
# 13  A charging attack. One quarter of the damage i...
# 14                                                 15
# 15  A charging tackle attack. One quarter of the d...
# 16                                                 20
# 17  A WATER-type attack. Has a one-in-three chance...
# 18                                                 25
# 19  A WATER-type attack. Stronger than BUBBLE. Man...
# 20                                                 10
# 21  An ICE-type attack. Has a one-in-ten chance of...
# 22                                                  5
# 23  The strongest ICE-type attack. Has a one-in-te...
# 24                                                  5
# 25  An extremely powerful attack. The attacker bec...
# 26                                                 25
# 27  The strongest FIGHTING attack. One quarter of ...
# 28                                                 20
# 29  A FIGHTING-type attack. Throws the target with...
# 30                                                 20
# 31  A non-stop attack move. The user's ATTACK powe...
# 32                                                 10
# 33  A move for learning one of the opponent's move...
# 34                                                 15
# 35  Creates illusionary copies of the user. The co...
# 36                                                 20
# 37  Reduces damage from physical attacks by about ...
# 38                                                 10
# 39  The user waits for several turns. At the end, ...
# 40                                                 15
# 41  In the first turn, the attacker tucks in its h...
# 42                                                 10
# 43  The user takes a nap to fully restore its HP a...
# 44                                                 10
# 45  Uses 1/4 of the user's maximum HP to create a ...
# 46                                                 30
# 47  A NORMAL-type attack. Also used for cutting sm...
# 48                                                 15
# 49  A WATER-type attack. The power of this techniq...
#
#                                                     6  \
# 0                                     TM & HM Attacks
# 1                                            Effect %
# 2                                                  --
# 3   A two-turn attack with the wind attack in the ...
# 4                                                  --
# 5   A special move that greatly boosts the user's ...
# 6                                                  --
# 7   A NORMAL-type attack. Out of all the Pokémon k...
# 8                                                  --
# 9   A technique that badly poisons the target. The...
# 10                                                 33
# 11  A NORMAL-type attack. Has a one-in-three chanc...
# 12                                                 --
# 13  A charging attack. One quarter of the damage i...
# 14                                                 --
# 15  A charging tackle attack. One quarter of the d...
# 16                                                 33
# 17  A WATER-type attack. Has a one-in-three chance...
# 18                                                 --
# 19  A WATER-type attack. Stronger than BUBBLE. Man...
# 20                                                 10
# 21  An ICE-type attack. Has a one-in-ten chance of...
# 22                                                 10
# 23  The strongest ICE-type attack. Has a one-in-te...
# 24                                                 --
# 25  An extremely powerful attack. The attacker bec...
# 26                                                 --
# 27  The strongest FIGHTING attack. One quarter of ...
# 28                                                 --
# 29  A FIGHTING-type attack. Throws the target with...
# 30                                                 --
# 31  A non-stop attack move. The user's ATTACK powe...
# 32                                                 --
# 33  A move for learning one of the opponent's move...
# 34                                                 --
# 35  Creates illusionary copies of the user. The co...
# 36                                                 --
# 37  Reduces damage from physical attacks by about ...
# 38                                                 --
# 39  The user waits for several turns. At the end, ...
# 40                                                 --
# 41  In the first turn, the attacker tucks in its h...
# 42                                                 --
# 43  The user takes a nap to fully restore its HP a...
# 44                                                 --
# 45  Uses 1/4 of the user's maximum HP to create a ...
# 46                                                 --
# 47  A NORMAL-type attack. Also used for cutting sm...
# 48                                                 --
# 49  A WATER-type attack. The power of this techniq...
#
#                                                     7  \
# 0                                     TM & HM Attacks
# 1                                                 NaN
# 2                                                 NaN
# 3   A two-turn attack with the wind attack in the ...
# 4                                                 NaN
# 5   A special move that greatly boosts the user's ...
# 6                                                 NaN
# 7   A NORMAL-type attack. Out of all the Pokémon k...
# 8                                                 NaN
# 9   A technique that badly poisons the target. The...
# 10                                                NaN
# 11  A NORMAL-type attack. Has a one-in-three chanc...
# 12                                                NaN
# 13  A charging attack. One quarter of the damage i...
# 14                                                NaN
# 15  A charging tackle attack. One quarter of the d...
# 16                                                NaN
# 17  A WATER-type attack. Has a one-in-three chance...
# 18                                                NaN
# 19  A WATER-type attack. Stronger than BUBBLE. Man...
# 20                                                NaN
# 21  An ICE-type attack. Has a one-in-ten chance of...
# 22                                                NaN
# 23  The strongest ICE-type attack. Has a one-in-te...
# 24                                                NaN
# 25  An extremely powerful attack. The attacker bec...
# 26                                                NaN
# 27  The strongest FIGHTING attack. One quarter of ...
# 28                                                NaN
# 29  A FIGHTING-type attack. Throws the target with...
# 30                                                NaN
# 31  A non-stop attack move. The user's ATTACK powe...
# 32                                                NaN
# 33  A move for learning one of the opponent's move...
# 34                                                NaN
# 35  Creates illusionary copies of the user. The co...
# 36                                                NaN
# 37  Reduces damage from physical attacks by about ...
# 38                                                NaN
# 39  The user waits for several turns. At the end, ...
# 40                                                NaN
# 41  In the first turn, the attacker tucks in its h...
# 42                                                NaN
# 43  The user takes a nap to fully restore its HP a...
# 44                                                NaN
# 45  Uses 1/4 of the user's maximum HP to create a ...
# 46                                                NaN
# 47  A NORMAL-type attack. Also used for cutting sm...
# 48                                                NaN
# 49  A WATER-type attack. The power of this techniq...
#
#                                                     8  \
# 0                                     TM & HM Attacks
# 1                                                 NaN
# 2                                                 NaN
# 3   A two-turn attack with the wind attack in the ...
# 4                                                 NaN
# 5   A special move that greatly boosts the user's ...
# 6                                                 NaN
# 7   A NORMAL-type attack. Out of all the Pokémon k...
# 8                                                 NaN
# 9   A technique that badly poisons the target. The...
# 10                                                NaN
# 11  A NORMAL-type attack. Has a one-in-three chanc...
# 12                                                NaN
# 13  A charging attack. One quarter of the damage i...
# 14                                                NaN
# 15  A charging tackle attack. One quarter of the d...
# 16                                                NaN
# 17  A WATER-type attack. Has a one-in-three chance...
# 18                                                NaN
# 19  A WATER-type attack. Stronger than BUBBLE. Man...
# 20                                                NaN
# 21  An ICE-type attack. Has a one-in-ten chance of...
# 22                                                NaN
# 23  The strongest ICE-type attack. Has a one-in-te...
# 24                                                NaN
# 25  An extremely powerful attack. The attacker bec...
# 26                                                NaN
# 27  The strongest FIGHTING attack. One quarter of ...
# 28                                                NaN
# 29  A FIGHTING-type attack. Throws the target with...
# 30                                                NaN
# 31  A non-stop attack move. The user's ATTACK powe...
# 32                                                NaN
# 33  A move for learning one of the opponent's move...
# 34                                                NaN
# 35  Creates illusionary copies of the user. The co...
# 36                                                NaN
# 37  Reduces damage from physical attacks by about ...
# 38                                                NaN
# 39  The user waits for several turns. At the end, ...
# 40                                                NaN
# 41  In the first turn, the attacker tucks in its h...
# 42                                                NaN
# 43  The user takes a nap to fully restore its HP a...
# 44                                                NaN
# 45  Uses 1/4 of the user's maximum HP to create a ...
# 46                                                NaN
# 47  A NORMAL-type attack. Also used for cutting sm...
# 48                                                NaN
# 49  A WATER-type attack. The power of this techniq...
#
#                                                     9
# 0                                     TM & HM Attacks
# 1                                                 NaN
# 2                                                 NaN
# 3   A two-turn attack with the wind attack in the ...
# 4                                                 NaN
# 5   A special move that greatly boosts the user's ...
# 6                                                 NaN
# 7   A NORMAL-type attack. Out of all the Pokémon k...
# 8                                                 NaN
# 9   A technique that badly poisons the target. The...
# 10                                                NaN
# 11  A NORMAL-type attack. Has a one-in-three chanc...
# 12                                                NaN
# 13  A charging attack. One quarter of the damage i...
# 14                                                NaN
# 15  A charging tackle attack. One quarter of the d...
# 16                                                NaN
# 17  A WATER-type attack. Has a one-in-three chance...
# 18                                                NaN
# 19  A WATER-type attack. Stronger than BUBBLE. Man...
# 20                                                NaN
# 21  An ICE-type attack. Has a one-in-ten chance of...
# 22                                                NaN
# 23  The strongest ICE-type attack. Has a one-in-te...
# 24                                                NaN
# 25  An extremely powerful attack. The attacker bec...
# 26                                                NaN
# 27  The strongest FIGHTING attack. One quarter of ...
# 28                                                NaN
# 29  A FIGHTING-type attack. Throws the target with...
# 30                                                NaN
# 31  A non-stop attack move. The user's ATTACK powe...
# 32                                                NaN
# 33  A move for learning one of the opponent's move...
# 34                                                NaN
# 35  Creates illusionary copies of the user. The co...
# 36                                                NaN
# 37  Reduces damage from physical attacks by about ...
# 38                                                NaN
# 39  The user waits for several turns. At the end, ...
# 40                                                NaN
# 41  In the first turn, the attacker tucks in its h...
# 42                                                NaN
# 43  The user takes a nap to fully restore its HP a...
# 44                                                NaN
# 45  Uses 1/4 of the user's maximum HP to create a ...
# 46                                                NaN
# 47  A NORMAL-type attack. Also used for cutting sm...
# 48                                                NaN
# 49  A WATER-type attack. The power of this techniq...

# %%
# Cleaning data, starting with lvl up set
# This cell should have no errors if you're accessing the correct table
lvl_up_set = lvl_up_set.drop(0, axis=0)
header_row = 0
lvl_up_set.columns = lvl_up_set.iloc[header_row]
lvl_up_set = lvl_up_set.reset_index(drop=True)
lvl_up_set = lvl_up_set.drop(header_row)
lvl_up_set = lvl_up_set.loc[:, lvl_up_set.columns.notnull()]
lvl_up_set = lvl_up_set.rename(columns={'Att.': 'Power'})
lvl_up_set = lvl_up_set.iloc[::2]
lvl_up_set = lvl_up_set.reset_index(drop=True)
lvl_up_set = lvl_up_set.drop('Type',axis=1)
lvl_up_set['Power'] = lvl_up_set['Power'].str.replace('--','Status')
lvl_up_set['Level'] = lvl_up_set['Level'].replace('—',0)
lvl_up_set['Effect %'] = lvl_up_set['Effect %'].replace('--',0)
lvl_up_set = lvl_up_set.replace('--','Status', regex=True)
lvl_up_set = lvl_up_set.replace('_','0', regex=True)
lvl_up_set['Power'] = lvl_up_set['Power'].replace('??','Fixed')
lvl_up_set
# Out:
# 1 Level Attack Name   Power Acc.  PP  Effect %
# 0     0     Scratch      40  100  35         0
# 1     0      Harden  Status  100  30         0
# 2     0      Absorb      20  100  20         0
# 3    34      Absorb      20  100  20         0
# 4    39       Slash      70  100  20         0
# 5    46        Leer  Status  100  30         0
# 6    53  Hydro Pump     120   80   5         0

# %%
# attempitng to apply the same methods to TM moves
tm_set = tm_set.drop(0, axis=0)
header_row = 0
tm_set.columns = tm_set.iloc[header_row]
tm_set = tm_set.reset_index(drop=True)
tm_set = tm_set.drop(header_row)
tm_set = tm_set.loc[:, tm_set.columns.notnull()]
tm_set = tm_set.rename(columns={'Att.': 'Power'})
tm_set = tm_set.iloc[::2]
tm_set = tm_set.reset_index(drop=True)
tm_set = tm_set.drop('Type',axis=1)
tm_set['Power'] = tm_set['Power'].str.replace('--','Status')
tm_set['Power'] = tm_set['Power'].replace('??','Fixed')
tm_set['Effect %'] = tm_set['Effect %'].replace('--',0)
tm_set
# Out:
# 1  TM/HM #   Attack Name   Power  Acc.  PP Effect %
# 0     TM02    Razor Wind      80  74.6  10        0
# 1     TM03  Swords Dance  Status   100  30        0
# 2     TM05     Mega Kick     120  74.6   5        0
# 3     TM06         Toxic  Status    85  10        0
# 4     TM08     Body Slam      85   100  15       33
# 5     TM09     Take Down      90    85  20        0
# 6     TM10   Double-Edge     100   100  15        0
# 7     TM11   Bubble Beam      65   100  20       33
# 8     TM12     Water Gun      40   100  25        0
# 9     TM13      Ice Beam      95   100  10       10
# 10    TM14      Blizzard     120    90   5       10
# 11    TM15    Hyper Beam     150    90   5        0
# 12    TM17    Submission      80    80  25        0
# 13    TM19  Seismic Toss   Fixed   100  20        0
# 14    TM20          Rage      20   100  20        0
# 15    TM31         Mimic  Status   100  10        0
# 16    TM32   Double Team  Status   100  15        0
# 17    TM33       Reflect  Status   100  20        0
# 18    TM34          Bide  Status   100  10        0
# 19    TM40    Skull Bash     100   100  15        0
# 20    TM44          Rest  Status   100  10        0
# 21    TM50    Substitute  Status   100  10        0
# 22    HM01           Cut      50    95  30        0
# 23    HM03          Surf      95   100  15        0

# %%
pokemons_name = dfs[1]
pokemons_name = pd.DataFrame(pokemons_name[0])
pokemons_name = pokemons_name[0][0].replace('#','')
pokemons_name
file_name_lvl_up = '{} lvl up set'.format(pokemons_name)
file_name_tm_set = '{} tm moves'.format(pokemons_name)

# %%
lvl_up_set.to_csv(file_name_lvl_up)

# %%
tm_set.to_csv(file_name_tm_set)

# %%
# Making a total move set list

# Create an URL object
url = 'https://bulbapedia.bulbagarden.net/wiki/List_of_moves' # The pokemons page
# Create object page
page = requests.get(url)

# %%
all_df = pd.read_html(page)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-f8ce09fb2bc1> in <module>
# ----> 1 all_df = pd.read_html(page)
#
# D:\Anaconda\envs\learn-env\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# D:\Anaconda\envs\learn-env\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1084         )
#    1085     validate_header_arg(header)
# -> 1086     return _parse(
#    1087         flavor=flavor,
#    1088         io=io,
#
# D:\Anaconda\envs\learn-env\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     896
#     897         try:
# --> 898             tables = p.parse_tables()
#     899         except ValueError as caught:
#     900             # if `io` is an io-like object, check if it's seekable
#
# D:\Anaconda\envs\learn-env\lib\site-packages\pandas\io\html.py in parse_tables(self)
#     215         list of parsed (header, body, footer) tuples from tables.
#     216         """
# --> 217         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     218         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     219
#
# D:\Anaconda\envs\learn-env\lib\site-packages\pandas\io\html.py in _build_doc(self)
#     719             else:
#     720                 # try to parse the input in the simplest way
# --> 721                 r = parse(self.io, parser=parser)
#     722             try:
#     723                 r = r.getroot()
#
# D:\Anaconda\envs\learn-env\lib\site-packages\lxml\html\__init__.py in parse(filename_or_url, parser, base_url, **kw)
#     937     if parser is None:
#     938         parser = html_parser
# --> 939     return etree.parse(filename_or_url, parser, base_url=base_url, **kw)
#     940
#     941
#
# src/lxml/etree.pyx in lxml.etree.parse()
#
# src/lxml/parser.pxi in lxml.etree._parseDocument()
#
# TypeError: cannot parse from 'Response'
